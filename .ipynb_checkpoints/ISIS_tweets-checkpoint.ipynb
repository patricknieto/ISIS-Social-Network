# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:99% !important; }</style>"))
# Out:
# <style>.container { width:99% !important; }</style>

# %%
import pandas as pd
import csv
import os
import numpy
import copy
# %matplotlib inline
import numpy as np
import seaborn as sns
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from gensim import corpora, models, similarities, matutils
from gensim.corpora.dictionary import Dictionary
from sklearn.cluster import DBSCAN
from sklearn.decomposition import NMF, PCA
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from collections import Counter, defaultdict, OrderedDict
import seaborn as sns

# %%
import matplotlib.pyplot as plt

#Some nice plotting params
mpl.rcParams['figure.figsize'] = (8,5)
mpl.rcParams['lines.linewidth'] = 3
plt.style.use('ggplot')

# %% [markdown]
# # Load ISIS data set and clean tweets

# %%
df = pd.read_csv('/media/patrick/MY_EXTERNAL/ISIS/tweets.csv', parse_dates= [6])

# %%
df.username = df.username.str.lower()

# %%
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %%
def clean_tweet(tweet):
    ext = "http"
    text = tweet[:tweet.find(ext)].lower()
    text = re.sub("[^\S]", " ", text)
    text = re.sub("english translation ", "", text)
    textOnly = re.sub("[^a-zA-Z0-9@# ]", "", text)
    return(textOnly)

# %%
def remove_users(tweet):
    text = tweet.lower()
    textOnly = re.sub(r"@\w+", "", text)
    return(textOnly)

# %%
df.tweets = df.tweets.apply(clean_tweet)

# %%
infoDict = OrderedDict()
for r in df[['username','tweets']].iterrows():
    match = re.search('^rt', r[1][1])
    if match:
        m = list(re.findall(r"@\w+", r[1][1]))
        if m:
            username=m[0][1:]
            tweet=r[1][1][len('rt ' + m[0]):] +' @' + r[1][0]
    else:
        username=r[1][0]
        tweet=r[1][1]
    if username not in infoDict:
        user = {}
        user['affil'] = []
        user['hashtags'] = []
        user['tweets'] = []
        user['doc'] = ''
        infoDict[username] = user
    if tweet not in infoDict[username]['tweets']:
        infoDict[username]['tweets'].append(tweet)
        infoDict[username]['doc']+=' ' + tweet
    infoDict[username]['hashtags'].extend(re.findall('(?<=#)\w+', tweet))
    infoDict[username]['affil'].extend(re.findall('(?<=@)\w+', tweet))

# %% [markdown]
# ### Treat all the tweets from one user as a single document and vectorize

# %%
len(infoDict)
# Out:
# 1556

# %%
len(docs)
# Out:
# 1556

# %%
docs = []
for k, v in infoDict.items():
    docs.append(remove_users(v['doc']))

# %%
Tfidf_vectorizer = TfidfVectorizer(analyzer='word', #tokenizer=tokenize,
                                  ngram_range=(1,1), stop_words='english',
                                  token_pattern='\\b[a-z][a-z]+\\b')
tfidf_docs = Tfidf_vectorizer.fit_transform(docs)

# %%
count_vectorizer = CountVectorizer(analyzer='word',
                                  ngram_range=(1,3), stop_words='english',
                                  token_pattern='\\b[a-z][a-z]+\\b')
cv_tweets = count_vectorizer.fit_transform(docs)

# %% [markdown]
# treat each tweets seperately

# %%
Tfidf_vectorizer = TfidfVectorizer(analyzer='word', tokenizer=tokenize,
                                  ngram_range=(1,2), stop_words='english',
                                  token_pattern='\\b[a-z][a-z]+\\b')
tfidf_tweets = Tfidf_vectorizer.fit_transform(df.tweets)

# %% [markdown]
# --------------------------------------------------------------------------

# %%
from sklearn.utils.extmath import randomized_svd
U, Sigma, VT = randomized_svd(tfidf_docs, n_components=15,
                                      n_iter=5,
                                      random_state=None)

# %%
sigma = []
for k,v in enumerate(Sigma):
    sigma.append((k,v))

# %%
f = plt.scatter(*zip(*sigma))

# %% [markdown]
# Based on the sigma values from the resulting matrix we can choose a about 5 components to use in our NMF model in order to explain the most.....?

# %% [markdown]
# ### NMF decomposition

# %%
tfidf_docs.shape
# Out:
# (112, 34927)

# %%
num_topics = 5
model = NMF(n_components=num_topics, init='random', random_state=0)
nmf = model.fit_transform(tfidf_docs)

# %%
doc_cluster = [list(r).index(max(r)) for r in nmf]

# %%
print (doc_cluster[0:20])
print (doc_cluster[41:60])
print (doc_cluster[61:80])
print( doc_cluster[-40:-20])
# Out:
# [3, 3, 2, 3, 3, 3, 0, 0, 2, 3, 4, 0, 0, 4, 3, 3, 4, 0, 0, 3]
# [0, 0, 3, 1, 3, 3, 4, 3, 2, 3, 4, 3, 4, 1, 4, 0, 4, 2, 0]
# [0, 1, 1, 3, 3, 3, 0, 4, 4, 4, 3, 0, 3, 0, 3, 2, 2, 0, 3]
# [3, 2, 0, 2, 2, 2, 0, 1, 2, 2, 4, 0, 2, 4, 2, 0, 2, 3, 2, 3]

# %%
cluster_size = [0,0,0,0,0]
for v in doc_cluster:
    cluster_size[v]+=1
cluster_size
# Out:
# [410, 193, 253, 493, 207]

# %%
for r in df[['username']].iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x7fa66803ce60>

# %%
# create dictionary that maps a user to their specific cluster
user_docs = {}
for k, cluster in enumerate(doc_cluster):
    user_docs[df['username'].iterrows()[k]] = cluster
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-22386b16dcf7> in <module>()
#       2 user_docs = {}
#       3 for k, cluster in enumerate(doc_cluster):
# ----> 4     user_docs[df['username'].iterrows()[k]] = cluster
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2358                 return self[name]
#    2359             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2360                                  (type(self).__name__, name))
#    2361
#    2362     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'iterrows'

# %%
words = sorted([(i,v) for v,i in Tfidf_vectorizer.vocabulary_.items()])
topic_words = []
for r in model.components_:
    a = sorted([(v,i) for i,v in enumerate(r)],reverse=True)[0:7]
    topic_words.append([words[e[1]] for e in a])

# %%
# VINNY"S CODE!
# Create the a list of topic words but only inlude them if they are the highest among all clusters
# they also need to be weighted appropriately within their cluster


word_cluster = [(list(r).index(max(r)),max(r)) for r in model.components_.transpose()]
for i,r in enumerate(model.components_.transpose()):
    s = sorted(r)
    if (s[0]-s[1])/s[1]<0.25:
        word_cluster[i] = (-1,-1)
topic_words = []
for c in range(5):
    a = sorted([(v[1],i) for i,v in enumerate(word_cluster) if v[0]==c], reverse=True)[0:7]
    topic_words.append([words[e[1]] for e in a])

# %%
topic_words
# Out:
# [[(9643, 'isis'),
#   (11083, 'libya'),
#   (13276, 'oil'),
#   (17809, 'suicide'),
#   (4150, 'claim'),
#   (7949, 'government'),
#   (602, 'airstrike')],
#  [(7351, 'follow'),
#   (698, 'alaikum'),
#   (17985, 'suspension'),
#   (10400, 'khair'),
#   (2174, 'assalamu'),
#   (9953, 'jazakallah'),
#   (15626, 'retweet')],
#  [(9682, 'islamicstate'),
#   (3409, 'breaking'),
#   (1521, 'amaqagency'),
#   (9576, 'iraqi'),
#   (6941, 'fallujah'),
#   (11679, 'martyrdom'),
#   (13353, 'operation')],
#  [(9678, 'islamic'),
#   (17569, 'state'),
#   (1132, 'allah'),
#   (12615, 'muslims'),
#   (9670, 'islam'),
#   (5961, 'dont'),
#   (12602, 'muslim')],
#  [(18070, 'syria'),
#   (2139, 'assad'),
#   (881, 'aleppo'),
#   (15944, 'russian'),
#   (15189, 'rebels'),
#   (20557, 'ypg'),
#   (15972, 'saa')]]

# %% [markdown]
# -----

# %% [markdown]
# ## Creating Graph Edges

# %% [markdown]
# #### Currently:
# We have occurences of username strings in all tweets from each user
#
#
# #### We would like:
# agrregated pairwise co-occurrence of character strings in tweet for each username, Normalized by the sum of all tweet from both usernames being compared.

# %%
infoDict['mustaklash']
# Out:
# {'affil': ['mustaklash',
#   'warmonitor',
#   'sayedridha',
#   '1515ummah',
#   '1515ummah',
#   '1515ummah',
#   'grezz10',
#   'mankhalfahum',
#   'mankhalfahum',
#   'mankhalfahum'],
#  'doc': ' bismillah support by retweeting may allah reward you   mustafa al iraqi  @mustaklash   amaq showing the effects of iraqi aircraft shelling on the albuhawah area in the amiriyat fallujah yesterday  iraqi forces carried out a failed attack for the 4th time within a week with the air cover on subaihat area in qrmah northeast of falluja friday prayers in tawhid masjid in the city of fallujah  ongoing battles in the vicinity of farooq dam against pkk  full album  merciful among themselves  aspect of the distribution of food aid to poor muslims  album  friday prayers in masjid alribat in the city of sirte libya  targeting the apostate yemeni armys barracks in alwadi area with a mortar shells 81 mm   @warmonitor not ye medical test laboratories in the city of albukamal  full album  destroying a convoy and killing 17 of nusayri army soldiers in the vicinity of al bardah east of al qarytain city  amaq sahwat escaping after the failure of their attack on the is fighters sites in the eastern qalmoun yesterday  @sayedridha lightning advance the coalition have been bombing shaddadi since 2 days ago  destroying a convoy and killing 17 of nusayri army soldiers in the vicinity of al bardah east of al qarytain city  @1515ummah  ongoing battles in the vicinity of farooq dam against pkk  full album  @1515ummah  targeting the apostate yemeni armys barracks in alwadi area with a mortar shells 81 mm   @1515ummah this must burn the heart of the kuffar  a mujahid captive at the hands of ypg smiling because he has done his part  targeting the apostate pkk in silos acharkrak village east of ayn issa region with grad missiles  repelling sahwa attack on snakes mountain in eastern qalmoun  full album  70 elements of nusayri army were killed on athriyah  raqqah road   70 elements of nusayri army were killed on athriyah  raqqah road  @grezz10  this must burn the heart of the kuffar  a mujahid captive at the hands of ypg smiling because he has done his part  @mankhalfahum some wise words from your brother maghrebi   some wise words from your brother maghrebi  @mankhalfahum  amaq showing the effects of iraqi aircraft shelling on the albuhawah area in the amiriyat fallujah yesterday  @mankhalfahum',
#  'hashtags': [],
#  'tweets': ['bismillah support by retweeting may allah reward you   mustafa al iraqi  @mustaklash  ',
#   'amaq showing the effects of iraqi aircraft shelling on the albuhawah area in the amiriyat fallujah yesterday ',
#   'iraqi forces carried out a failed attack for the 4th time within a week with the air cover on subaihat area in qrmah northeast of falluja',
#   'friday prayers in tawhid masjid in the city of fallujah ',
#   'ongoing battles in the vicinity of farooq dam against pkk  full album ',
#   'merciful among themselves  aspect of the distribution of food aid to poor muslims  album ',
#   'friday prayers in masjid alribat in the city of sirte libya ',
#   'targeting the apostate yemeni armys barracks in alwadi area with a mortar shells 81 mm  ',
#   '@warmonitor not ye',
#   'medical test laboratories in the city of albukamal  full album ',
#   'destroying a convoy and killing 17 of nusayri army soldiers in the vicinity of al bardah east of al qarytain city ',
#   'amaq sahwat escaping after the failure of their attack on the is fighters sites in the eastern qalmoun yesterday ',
#   '@sayedridha lightning advance the coalition have been bombing shaddadi since 2 days ago',
#   ' destroying a convoy and killing 17 of nusayri army soldiers in the vicinity of al bardah east of al qarytain city  @1515ummah',
#   ' ongoing battles in the vicinity of farooq dam against pkk  full album  @1515ummah',
#   ' targeting the apostate yemeni armys barracks in alwadi area with a mortar shells 81 mm   @1515ummah',
#   'this must burn the heart of the kuffar  a mujahid captive at the hands of ypg smiling because he has done his part ',
#   'targeting the apostate pkk in silos acharkrak village east of ayn issa region with grad missiles ',
#   'repelling sahwa attack on snakes mountain in eastern qalmoun  full album ',
#   '70 elements of nusayri army were killed on athriyah  raqqah road ',
#   ' 70 elements of nusayri army were killed on athriyah  raqqah road  @grezz10',
#   ' this must burn the heart of the kuffar  a mujahid captive at the hands of ypg smiling because he has done his part  @mankhalfahum',
#   'some wise words from your brother maghrebi ',
#   ' some wise words from your brother maghrebi  @mankhalfahum',
#   ' amaq showing the effects of iraqi aircraft shelling on the albuhawah area in the amiriyat fallujah yesterday  @mankhalfahum']}

# %%
def is_retweet(tweet):
    match = re.search('^rt', tweet)
    if match:
        return True
    return False

# %%
def check_string(string):
    return string in df.username.unique()

# %%
count=0
rt = []
for tweet in df.tweets:
    m = re.findall(r"^rt @", tweet)
    if m:
        count+=1
        rt.append(tweet)
count
#len(set(rt))
# Out:
# 0

# %%
len(infoDict)
# Out:
# 108

# %%
len(set(all_mentioned_users))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-e98d48c5e68e> in <module>()
# ----> 1 len(set(all_mentioned_users))
#
# NameError: name 'all_mentioned_users' is not defined

# %% [markdown]
# NODES

# %%
# create the nodes for the graph. Dictionary keys as usernames 
# with each item in the value list being a connection with number of times mentioned
# NOTE!! this is for every mentioned user

nodes = defaultdict(str)
for K, V in infoDict.items():
    nodes[K] = [(k, v) for k,v in Counter(list(V['affil'])).items() if k != K]
for k, v in list(nodes.items()):
    if not v:
        del nodes[k]

# %%
# create the nodes for the graph. Dictionary keys as usernames 
# with each item in the value list being a connection with number of times mentioned
# NOTE!! this is only for users within the starting data set

nodes = defaultdict(str)
for K, V in infoDict.items():
    nodes[K] = [(k, v) for k,v in Counter(list(filter(check_string, (V['affil'])))).items() if k != K]
for k, v in list(nodes.items()):
    if not v:
        del nodes[k]

# %%
#create dictionary that maps usernames to a uniqe ID and the cluster they belong to
# user_docs = a list of documents per user

ID = defaultdict()
for k, v in enumerate(list(nodes.items())):
    ID[v[0]] = k, user_docs[v[0]]
    for i in range(0, len(v[1])):
        try:
            ID[v[1][i][0]] = k, user_docs[v[1][i][0]]
        except:
            pass

# %%
df2 = pd.DataFrame(ID).T

# %%
nodes['ramiallolah']['affil'].most_common()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-755-2f3e730acbca> in <module>()
# ----> 1 nodes['ramiallolah']['affil'].most_common()
#
# TypeError: list indices must be integers or slices, not str

# %%
# save the nodes as a csv
pd.DataFrame(ID).T.to_csv('nodes2.csv')

# %%
# create dict with a source, target tied to a weight
edge_dict = {}
for k, v in nodes.items():
    for i in range(len(v)):
        try:
            edge_dict[ID[[k][0]][0], ID[v[i][0]][0]] = v[i][1]
        except:
            pass

# %%
pd.DataFrame([[k[0],k[1],v] for k, v in edge_dict.items()]).to_csv('edges2.csv')

# %%
for k, v in edgeDict.items():
    edgeDict[k] = [word for item in v for word in item if word in list(set(df.username))]
for k, v in list(edgeDict.items()):
    if not v:
        del edgeDict[k]

# %%
for k, v in edgeDict.items():
    for name in v:
        if name == k:
            v.remove(name)

# %% [markdown]
# Focusing on retweets

# %%
tweet = ' rt @mention this is a retweet'

# %%
retweets = defaultdict(list)
original = defaultdict(list)
all_mentioned_users = df.username.unique().tolist()
for tweet in df.tweets:
    
    m = list(re.findall(r"@\w+", tweet))
    all_mentioned_users.extend(set(m))
    
    match = re.search('^rt', tweet)
    if match:
        if m:
            retweets[m[0][1:]].append(tweet[len('rt ' + m[0]):])
            if m[0]=='@danielcollins85':
                print(tweet)
# Out:
# rt @danielcollins85 speculativeemotive bbc report on alleged russian strike on @msf do they report usuk bombs on innocents similarly

# %%
retweets = defaultdict(list)
original = []
all_mentioned_users = df.username.unique().tolist()
for tweet in df.tweets:
    match = re.search('^rt', tweet)
    if match:
        m = list(re.findall(r"@\w+", tweet))
        l = ' '.join(m)
        if m:
            retweets[m[0][1:]].append(tweet[len('rt ' + l):])
        all_mentioned_users.extend(m)
    else:
        original.append(tweet)

# %%
for k, v in enumerate(set(all_mentioned_users)):
    nodes
# Out:
# 150

# %%
len([i for c in retweets.values() for i in c])
# Out:
# 5824

# %%
original
# Out:
# defaultdict(list,
#             {'04_8_1437': ['#amaqagency martyrdom operation with rigged vehicle hits a gathering of the shiite popular mobilization  #baghdad',
#               '#amaqagency 3 children killed by russian airstrikes on #raqqah city yesterday  #islamicstate #khilafahnews',
#               '#amaqagency  approximately 70 killed and dozens wounded after a martyrdom operation in #baghdads sadr city',
#               '#amaqagency iraqi forces reconnaissance plane shot down east of #fallujah  #islamicstate #khilafahnews',
#               '#amaqagency thwarted assault by syrian opposition factions on positions of islamic state forces  #qalamun',
#               '#amaqagency 2 martyrdom operations with explosive belts hit #baghdads kazimiyyah area and the adl neighborhood',
#               '#amaqagency #islamicstate forces capture mahjurah brigade near t4 airbase in eastern #homs countryside ',
#               '#amaqagency #islamicstate fighters repel syrian opposition attack on the tanaf border crossing between #iraq',
#               '#amaqagency 4 kurdish units killed after #islamicstate fighters infiltrate inad village  #shaddadi #hasakah',
#               '#amaqagency  25 syrian regime soldiers killed as #islamicstate fighters repel a convoy  #huwaysis #homs',
#               '#amaqagency #islamicstate fighters assault a checkpoint of kurdish units in abu fas village  #shaddadi #hasakah',
#               '#amaqagency 10 kurdish units killed during ongoing battles south of #shaddadi city  #islamicstate #khilafahnews',
#               '#amaqagency martyrdom operation hits a gathering of iraqi forces during clashes in the jubbah area  #baghdadi',
#               '#amaqagency  aftermath of russian bombing on the city yesterday',
#               '#amaqagency us airstrikes kill a man and wound 7 others as their thread production workshop  #dabiq #aleppo',
#               '#amaqagency explosion of 2 boobytrapped homes hits kurdish units in the village of umm dhiban west of #sinjar',
#               '#amaqagency martyrdom operation hits syrian opposition fighters as they enter the village of yahmul #azaz #aleppo',
#               'medical source to #amaqagency 12 civilians killed and 10 others wounded in russian bombing on shuhayl  #deirezzor',
#               '#amaqagency #islamicstate fighters thwart an assault by syrian regime forces from 3 axes on the mahjurah  #homs',
#               '#amaqagency 10 syrian regime soldiers killed in addition to a tank and a 23 mm artillery cannon destroyed  #homs',
#               '#amaqagency #islamicstate forces launch massive assault on iraqi army positions in #hamidiyyah and  #fallujah',
#               '#amaqagency 2 commandos detonate their explosive belts inside #zaydan police headquarters southwest of #baghdad',
#               '#amaqagency  #islamicstate forces capture the areas of albu ithah and albu farraj north of #ramadi after',
#               '#amaqagency martyrdom operation hits a gathering of hadis militias in the khalaf area of #mukalla  #hadramaut',
#               '#amaqagency  #islamicstate fighters assault #jurayishi and #tarrah highway north of #ramadi destroying 3 iraq',
#               '#amaqagency martyrdom operation with rigged armored vehicle hits iraqi army base on #tarrah highway  #ramadi',
#               '#amaqagency at least 30 iraqi soldiers killed in addition to the destruction of a bmp a hummer and a bulldozer during ongoing  #rama',
#               '#amaqagency iraqi forces reconnaissance plane shot down by #islamicstate fighters yesterday east of #fallujah city ',
#               '#amaqagency  syrian regime tank destroyed and its crew killed near #huwaysis area in #homs countryside after',
#               '#amaqagency #islamicstate forces interrupt iraqi forces supply lines to #jurayishi and albu hayis from  #ramadi',
#               '#amaqagency #islamicstate forces assault iraqi forces on the outskirts of #jubbah area northwest of #baghdadi city',
#               '#amaqagency 2 martyrdom operations with a rigged hummer and a rigged car hit fortifications of iraqi  #fallujah',
#               '#amaqagency 3 kurdish units killed yesterday as islamic state fighters infiltrate the village  #kobani  #aleppo',
#               '#amaqagency syrian regime and opposition attempts to advance in #homs and #damascus as kurdish units  #hasakah',
#               '#amaqagency  martyrdom operation with explosive belt hits a gathering of members of parliament in the  #maiduguri',
#               '#amaqagency #breaking 5 iraqi soldiers killed by sniper fire in #zobaa southwest of #baghdad  #khilafahnews',
#               '#amaqagency android app in english  download amaq agency app v10 ',
#               '#amaqagency app',
#               '#amaqagency app',
#               '#amaqagency  #islamicstate fighters retake #yahmul east of #azaz city in #aleppos northern countryside',
#               'rt  #    #      #     #',
#               'rt  #  #     #  #  #    ',
#               'rt   # ',
#               '#amaqagency prophetic hadith memorization contest in #raqqahs countryside  #islamicstate #khilafahnews',
#               '#amaqagency syrian regime 23 mm artillery piece destroyed by a guided missile in the jazal area of #homs countryside',
#               '#amaqagency destruction of iraqi forces tank with guided missile in jurayishi area north of #ramadi ',
#               'rt           ',
#               '      ',
#               '     '],
#              '06230550_is': ['current situation map of wilayat kheyr#is closing in on the assadists',
#               'follow and rt please',
#               '1the irony of sahwat is that they make excuses for the kufr of democracy amp alliance with kuffar yet bash amp condemn #is all the time f',
#               'rt  if you  need direct link this is a  youtube link plz watch and retweet',
#               'rt  when a new land is opened by the muslims',
#               'rt  two red sea islands shed light on ties between #israel amp #saudi arabia',
#               'rt  a brother sent me this nasheed really good for those who raise #shyukh above the #quran and #sunnah mashaallaah',
#               'rt  hed give kids dates like giving kids sweets nowadays to bribe them to keep others away from disturbing his time with the ble',
#               'rt  the size of the gates of jannah',
#               'rt  when the ansaar    started to cry until their beards were wet subhana allah',
#               'rt  we obtained headcam footage taken from a dead islamic state fighter',
#               'rt  alwala walbara according to the aqeedah of the salaf by muhammad saeed alqahtani parts 123',
#               'rt  pt the icsr report recommends that the west promotes the voices of sellouts like yasir qadhi to counter awlaki',
#               'rt  #sahabahseries albar bin mlik      part 1',
#               'rt  must read  the blessed shaam and the wisdom of yemen   the withdrawal from almukallah   ',
#               'rt  we will be modern but we wont be you',
#               'rt  isis cells and al salul apostates clashing near mecca'],
#              '1515ummah': ['asalam alikum la familia #is',
#               'dawlah islamiya baqiyah baqiyah wa tatamadad',
#               'kuffar are pathetic wasting all their time reporting our twitter when we got kids handing out accounts like candy  #isis #dieinyourra',
#               ' jazakallah khair ukh',
#               ' jazakallah kha',
#               '#islamicstate #haqq #isis #turjmantweets',
#               'alhumdullilah #isis ',
#               'rt  #isis inflicted on usa what could arguably be called the greatest geopolitical defeat of their history  alqaeda has n',
#               'rt  alqaedas masters the taliban can claim to have also fought the usa the global superpower but the war in afghanist',
#               'rt  alqaeda has practically zero actual combat experience against usa and even now usa is hardly concerned by them figu',
#               'rt  of course usa doesnt even need alqaeda to retreat anywhere when they can just prop up a couple prison scholars to ea',
#               '#isis took menagh airbase amp were fighting in #allepo until criminal fsa gangs stabbed them in the back i have 0 sympathy for these sc',
#               'rt  the muslims near the end of times',
#               ' i remember very well aki now let the traitors die in their ra',
#               'rt  reports by regime media that #saa now controls jib alkalb in e #aleppo an #isis territory are untru',
#               'rt  #isis sources #is repels #turkish ground troops incursion attempt near the border crossing in #jarablus',
#               ' they are also the ene',
#               'rt  so fsa had sign treaty where  ypg was supposed  to implement sharia law hahahahahahahaha ',
#               'bismill',
#               'rt  ypg fan boys blame turkey for bombing azaz hospital yet it was russia ypg fan boys it was terrorists hospital',
#               'next time try say dawlah lost so amp so area tell them #dieinyourrage #baqiyah #isis ',
#               'indoor football courts #mosul #isis',
#               'which jahil said the dawlah banned football its game over when i get on the court inshallah  #is',
#               'rt  not only thattheyd also rape thousands of their women the story of bosnia tears my heartleasson learnedgt #baqiya',
#               'rt  assad is humiliating himself by supporting the communist terrorist group ypg that seeks to occupy syri',
#               'beware of the treacherous #ummah #isis',
#               'rt  kurdish pyd seizure of azaz corridor is probably most widely accepted worldwide campaign of ethnic cleansing in rece',
#               ' whatever you clo',
#               'rt  #aleppo  cluster bombs and rockets hit albab just recent',
#               'rt  #hasakah  10 civilians killed when airstrikes hit civilian cars on their road to aljayar village in mount abdul aziz ar',
#               'rt  #salahuddin  4 hashd shaabi militants killed and 2 humvees destroyed in yesterday clashes west of #samar',
#               'rt  #anbar  iraqi army bulldozer was destroyed by guided missile in albu aytha area north of #rama',
#               '#wilayatarraqqah tabqa city at night ',
#               '#wilayatarraqqah aspects from the work of service department in tabqa city ',
#               '#wilayatninawa mosul city at night ',
#               '#wilayatarraqqah  the work of the electricity department in the city of raqqa ',
#               '#wilayatalfallujah implementing hadd punishment on two senior rafidi intelligence officers',
#               '#wilayatdijlah khilafah soldier pounding the safavid army and the hashd rafidi in the area of alasmadah',
#               '#wilayathalab   targeting nusayri army tank with guided missile in the vicinity of kwerys airport',
#               '#wilayathalab examination for masjid imams after attending a religious course in akhtarin ',
#               '#wilayatninawa   a quick tour of mosul aljadida neighborhood',
#               '#wilayatdayala   sunset at hamrain mountain  ',
#               '#wilayathims  aspect of the work of diwan zakat in the state of homs ',
#               '#wilayatalfallujah   sunset in the city of fallujah ',
#               '#wilayathalab  aspect of daily life of dawlah citizen in the district of alraai ',
#               '#amaqnews religious course for 1200 functionaries of public services in sirte details',
#               '#wilayatninawa activity of diwan of dawah amp masajid in the city of mosul ',
#               '#wilayattarabulus   rain in the city of sirte  ',
#               '#wilayatalanbar two eyes shall not be touched by the fire ',
#               '#maktabatalhimmah #billboard a days ribat in the cause of allah ',
#               '#wilayathims   distributing an naba newsletter to citizen in the city of sukhnah ',
#               '#maktabatalhimmah #billboard whoever takes care of a fighters family has participated in the battle',
#               '#wilayatarraqqah  aspects of the work of the oversight and inspection office in the city of tabqah',
#               '#maktabatalhimmah #billboard establishing the religion with a guiding book and a helping sword',
#               '#wilayatnorthbaghdad   the bombing of the barracks of safavid army at siyatak area and complex of aljiku',
#               '#wilayatsalahuddin   pounding gatherings of rafidi military with cannon in northern city of tikrit',
#               '#wilayattarabulus  a chicken shops in sirte',
#               '#maktabalhimmah pdf wajib salah jamaah  arabic  ',
#               '#wilayatdijlah competition in darul alislam to memorize alquran alkarim ',
#               '#wilayatalfallujah   attack of the soldiers of khilafah on the safavid army barracks in saqlwiyyah',
#               '#wilayatkarkuk  paving streets in the town of alhawija ',
#               '#amaqnewsagency #infographic    35 million dollars distributed by the diwan of zakah in syria within a month',
#               ' the media office of ajnad presents  tilawah li surat alanam ',
#               '#amaqnewsagency    glimpse of first semester exams at mosul universitys faculty of medicine ',
#               '#wilayatninawa constructing a playpark for children in the area of alqusur mosul ',
#               '#wilayatninawa a quick tour of alburiso market in mosul city ',
#               '#wilayatbarqah  establishing the hadd on a thief in the city of benghazi ',
#               '#wilayatsalahuddin   a glimpse into battle in the west of samarra against rafidi militia ',
#               '#wilayatsalahuddin picture west of the city of tikrit ',
#               '#wilayatdayala  picture of aladzim river '],
#              '432mryam': ['please followsupport',
#               ' jazakallah khair dear ukhti',
#               ' jazakallah khair',
#               ' upp0rt our ukhti     ',
#               ' jazakallah khair sis',
#               ' upp0rt',
#               '   jazakallah kha',
#               '      jazakallah kha',
#               '',
#               '',
#               'the beauty of life does not depend on how happy you are but how happy others can be because of you',
#               ' jazakallah kha',
#               'never let fear determine  who you are and never let where  you have been  determine where you are going',
#               'the things we take for granted someone else is praying for',
#               ' jazakallah khair dear ukhti awww so cute',
#               'rt  people often judge people  without knowing  the phase they are going trough',
#               'rt  the fashioner is none but allah swt',
#               'rt  youve been blessed with another day make the most of it  death may await you at the end of i',
#               'rt  ya allah keep our hearts firm on islam  and let us die as muslims',
#               'no matter what others may put on you forgive and keep trying the only one to please is allah the only one to judge is allah',
#               'upp0rt     ',
#               'i could post kindness tweets all day but they fall on deaf ear',
#               '',
#               'if you succeed in deceiving someone dont think that  person is a fool realize the person trusted  you much more than  you deserve',
#               '',
#               '',
#               'rt   so sweet things ',
#               'rt  sh ibn uthaymn  everyone no matter what level they have reached is in need of allh for guidance   tafsr s',
#               'upp0rt',
#               'upp0rt',
#               'upp0rt',
#               ' wa iyyak ak',
#               ' wa iyyak ak',
#               'rt  life is going by you dont have time to waste being negative you have a never ending life after death to work fo',
#               'rt  didnt know terrorists do this kind of stuff how nice of them may allah guide them',
#               'rt  second batch of russian jets leaves #syria airbase',
#               'upp0rt',
#               'upport our dear ukhti ',
#               ' wa iyyaki dear ukhti',
#               'upport our ukhti    ',
#               '   jazakallah khair habibti',
#               'upp0rt       ',
#               ' jazakallah khair dear sis',
#               'upport our dear ukhti    ',
#               ' jazakallah kha',
#               ' jazakalkah kha',
#               ' jazakallah kha',
#               'upp0rt     ',
#               ' wa iyyaki s',
#               ' wa iyyaki habibti',
#               ' jazakallah khair sweet sis lol pic',
#               'upp0rt',
#               ' wa iyyak ak',
#               'upp0rt    ',
#               'people may try to break your spirit and pull you down forgive and pray for them allah is all you need',
#               '',
#               'upp0rt      ',
#               '  wa iyyak ak',
#               'upport our dear ukhti   ',
#               'be willing to go alone not everyone who  who started with you will finish with you',
#               ' wa iyyaki ukhti',
#               'upp0rt',
#               'upp0rt',
#               'rt  you have got to be more interested in pleasing allah    than you are in pleasing people',
#               'rt  the life of this duniya is only the enjoyment of deception quran 3185',
#               'rt  the hereafter is better and lasting',
#               'rt  every soul shall taste death  then unto us you shall be returned',
#               ' jazakallah khair ak'],
#              '___ku217_y': ['         217    ',
#               '         anyasi',
#               '   ',
#               '   ',
#               '   ',
#               '  ',
#               '   ',
#               '#             # ',
#               '#   #       10          #',
#               '#                ',
#               '#   #         #  #',
#               '#   #               #',
#               '             ',
#               '#    #        #  # ',
#               '#               30      ',
#               '#       #              ',
#               '#amaq islamic state fighters capture syrian air force pilot after shooting down his plane 30 km from mt dakwah in the eastern countrysi',
#               '#amaqagency  islamic state fighters capture syrian air force pilot after shooting down his plane 30 km from mt dakwah in the easter',
#               'countryside of #damascu',
#               '#amaqagency the pilot azzam eid from #hamah was apprehended after landing with his parachute near his planes crash site east of #damasc',
#               '#   #              #',
#               '#             #   #      1',
#               ' #          ',
#               '   ',
#               '#       ',
#               '   ',
#               '# #              36',
#               '# #          720',
#               '#amaqagency #deir ezzor clashes between islamic state fighters and syrian regime forces on the outskirts 36',
#               '#amaqagency #deir of the industrial neighborhood 72',
#               '#  #              #  #'],
#              '__alfresco__': ['rt  reminder for my brothers and sisters specifically those here in the islamic state  the vast majority of journalists are ac',
#               'rt  #aqap sympathizers on  claim militants withdrew to protect save mukalla from the wrath of war aha sure yeah #yem',
#               'massage during the day and calling daesh khawarij during the night',
#               'rt  breaking news  a huge number of the #iraqi army and militants withdrawn from karma area after suffered heavy loses by #is n',
#               'when will you people know that protests will never help you  some people just never get it  especially egyptian',
#               'blame yourself',
#               'rt   like i said you only need to throw a bomb belgian politics will finish the job for yo',
#               'f   ',
#               ' yes thats why sisi is ther',
#               ' wa fee',
#               ' ame',
#               'oh im sure the effects of daily airstrikes by us is much more severe and devastating than this',
#               ' morsi was there because of them and then came along sisi because of their stupidity of turning to democrac',
#               'the people of fallujah dont need your aid',
#               ' and morsi is the head clown of the clow',
#               'rt  israel kidnaps amp violates muslim girls in their dungeons  saudi are too busy flirting with them in the sea ',
#               'f   ',
#               'rt  what people really think',
#               ' blo',
#               'meanwhile on reddit  the islamic state is a modern state which reflect the true image of islam',
#               'rt  video showing sunni citizen executed after brutally being tortured by iraqi #shia militants',
#               ' just messing with y',
#               'while youre at it how about making iraq a state of us',
#               'rt  amaq publishes video of turkish artillery fire  near dabiq',
#               'dua',
#               'more and more airstrikes bls',
#               'ameen',
#               'speaking of airstrikes germany plans to build 65 m airbase in turkey for operations against the islamic state',
#               'ameen',
#               'rt  help if they stop their destructive and deadly airstrikes',
#               'f   ',
#               ' oh great dont you sta',
#               ' i miss salah ad din al kurdi the most radical twe',
#               'can you not tweet your pic on the tl pl',
#               ' lol what is tha',
#               'rt  the gay rights activist killed today in bangladesh ran a gay magazine which was funded by usaid a charity',
#               'rt  #karmah  dozens elements of murtad iraqi government forces killed and injured on the outskirts of #karmah #fallujah  no furthe',
#               ' interview what sort of intervie',
#               'when salul is not bombing muslims in other lands they are oppressing muslims in their own lands  village destroyed',
#               'rt  activists speak of a significant decline of flower prices in #fallujah after a good start of the harvest season   alhamdu li ',
#               'rt  alqaeda jabhat alnusra and the secular fsa impose a seige and boycott on daraa causing hardship tp civilians',
#               'f   ',
#               'islamic state fighters detonate a car bomb on a gathering of syrian regime forces in the sayyidah zaynab area in damascus  #am',
#               'breaking  8 killed including 3 children and 13 wounded after iraqi air force bombing on fallujah city  #amaqagen',
#               'thwarted us and turkeybacked syrian opposition attempt to advance in aleppos northern countryside  #amaqagency',
#               'dua',
#               ' youre still not getting umm ibrah',
#               ' prove it',
#               'rt  when the time of prayer comes the islamic state isis cease all activities and make people pray location mosul',
#               'rt  it seems  is a drug dealer dont follow him unless you are a crack who',
#               'rt  150 afghan childrens minds being poisoned with kufr and shirk in iran so they can return back to afghanistan  ',
#               'rt  video from fallujah hospital yesterday after massacre of civilians',
#               'rt  #fallujah did not bow for anyone but allaah and allaah rewarded them with blessings in their harvest  ',
#               'rt  make yourself submissively gentle to your parents with good compassion they also took care of you',
#               'rt  isis steps up attacks against ahrar ashsham leaders following their fight against isis in n aleppo under us orders',
#               'f   ',
#               'f   ',
#               'rt  labib nahhas tweeting from his deluxe suite in a luxury hotel in geneva where he negotiates with the regime',
#               'rt  while syrian rebels compete to impress us and russia us and russia decide which one of the groups are terrorists',
#               'dua',
#               'rt  this is how assad animals react to bombardments on women and children ',
#               'rt  a proassad journalist takes a smiling selfie near the dead bodies of syrian civilians who were tortured to death',
#               'rt  #jn #aq spokesperson harshly attack #ahrar alsham with an endless list of accusation #syria',
#               'rt  no need to worry about #russian invasion in #syria one friday sermon in #mecca declaring defensive jihad is more th']})

# %%
len([i for c in original for i in c])
# Out:
# 1581

# %%
rtwts = {}
users = []
for rt in infoDict['ramiallolah']['rts']:
    users.extend(re.findall('(?<=@)\w+', rt))
    rtwts['ramiallolah'] = [(k, v) for k,v in Counter(users).items() if k != 'ramiallolah']

# %%
# create dict with a source, target tied to a weight
edge2_dict = {}
for k, v in rtwts.items():
    for i in range(len(v)):
        try:
            edge2_dict[v[i][0], ID[k][0]] = v[i][1]
        except:
            pass

# %%
for k in infoDict.keys():
    for v in k['rts']:

# %% [markdown]
# -----

# %% [markdown]
# ### Time series analysis of all tweets grouped by day

# %%
perhr = df.set_index(pd.DatetimeIndex(df['time'])).resample('12H', how='count').resample('D', how='mean')

# %%
fig, ax = plt.subplots(figsize = (20,8))

perhr['2016-01-01':].numberstatuses.plot(ax = ax, color="r", fontsize=12)

yemen = '2016-01-29'
brussels = '2016-03-22'


# ax.plot(yemen,183,color = 'r',
#         marker = 'o',
#         markersize = 20, 
#         linestyle = '',
#        markeredgewidth = 1.5
#        )

# ax.plot(brussels,183,color = 'r',
#         marker = 'v',
#         markersize = 20, 
#         linestyle = '',
#        markeredgewidth = 1.5
#        )


ax.annotate('Bombing in Brussels',xy=(brussels, 200),xytext=('2016-03-03', 310),
            arrowprops=dict(facecolor='white', shrink=0.05), size=15)

ax.annotate('Car bombing in Yemen',xy=(yemen, 200),xytext=('2016-01-10', 310),
            arrowprops=dict(facecolor='white', shrink=0.05),size=15)

ax.margins(None,0.1)
# ax.legend(['Tweets','Car bomb in Yemen','Bombing in Brussels'], loc = 'upper left', bbox_to_anchor=(0, 0.9),
#           numpoints = 1, labelspacing = 3.5, fontsize = 18)
ax.set_xlabel('Date')
ax.set_ylabel('Number of Tweets')
#ax.set_title('Frequency of ISIS Tweets in 2016')

# ax.spines['bottom'].set_color('w')
# ax.spines['top'].set_color('w') 
# ax.spines['right'].set_color('w')
# ax.spines['left'].set_color('w')

# ax.tick_params(axis='x', colors='w')
# ax.tick_params(axis='y', colors='w')

# ax.yaxis.label.set_color('w')
# ax.xaxis.label.set_color('w')

# ax.set_axis_bgcolor('w')
fig.savefig('temp.png')
plt.show()

# %%
style.available
# Out:
# ['seaborn-ticks',
#  'seaborn-dark',
#  'seaborn-colorblind',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-poster',
#  'seaborn-muted',
#  'seaborn-darkgrid',
#  'seaborn-notebook',
#  'seaborn-dark-palette',
#  'seaborn-talk',
#  'seaborn-white',
#  'ggplot',
#  'classic',
#  'bmh',
#  'seaborn-pastel',
#  'seaborn-deep',
#  'seaborn-whitegrid',
#  'dark_background',
#  'seaborn-paper',
#  'fivethirtyeight']

# %%
df3 = pd.DataFrame.from_dict(infoDict)

# %%
df3.T
# Out:
#                                                              affil  \
# gunsandcoffee70  [khalidmaghrebi, seifulmaslul123, cheerleaduni...
# giimediach004                                    [gunsandcoffee70]
# abulaythalhindi                         [ibnamaan, milatuibrahiim]
# yazeeddhardaa25  [yazeeddhardaa25, ibnnuhas, jazrawiuod, striv3...
# abubakerdimshqi  [tawheed1is, ironmuhajir2, jundhullah14, akhma...
# baqiyais         [abuyaqub6, alwalawalbara12, macroarch, ahwaal...
# abdelhakzait                     [nasseralfahad0, abubakerdimshqi]
# cnn                [abubakerdimshqi, maghrabiarabi, maghrabiarabi]
# pieternanninga   [yazeeddhardaa25, yazeeddhardaa25, maisaragher...
# muslimprisoners  [abubakerdimshqi, anjemchoudary, abubakerdimsh...
# 3bdulkaed6r                                      [yazeeddhardaa25]
# syrializer                                       [yazeeddhardaa25]
# ramiallolah      [yazeeddhardaa25, yazeeddhardaa25, yazeeddhard...
# sakirkhader      [yazeeddhardaa25, abdlrhmn15, mobi_ayubi, magh...
# thejokerdc                                       [yazeeddhardaa25]
# islamreligion                                    [abubakerdimshqi]
# markito0171      [yazeeddhardaa25, whitecat_7, whitecat_7, abub...
# sta92                                            [yazeeddhardaa25]
# ejmalrai         [yazeeddhardaa25, whitecat_7, bajwa47online, b...
# islamiceyes                                      [abubakerdimshqi]
# aimanofarabia                                    [abubakerdimshqi]
# freealeppo1985                                   [abubakerdimshqi]
# ayyx3                                            [abubakerdimshqi]
# pray4pal                                         [abubakerdimshqi]
# whitecat_7       [khadijavf, joinisnation82, princessbaqiya2, j...
# netzpolitik                                           [whitecat_7]
# amanlikeme                    [whitecat_7, whitecat_7, whitecat_7]
# eyeonmilitant                             [whitecat_7, whitecat_7]
# jihadologynet    [whitecat_7, 06230550_is, 06230550_is, abu_azz...
# conflicts        [alarabiyaen, whitecat_7, iucanalyst, bajwa47o...
# ...                                                            ...
# iraqispringmc                                     [mountainjjoool]
# globallibz                                        [mountainjjoool]
# saiyansyrian                                       [uncle_samcoco]
# observateurs                                       [uncle_samcoco]
# wsj                                                 [warreporter1]
# joogaza                                              [nidalgazaui]
# phmarliere                                         [uncle_samcoco]
# cnnturkeng                                        [mountainjjoool]
# mountainkkpouio                       [__alfresco__, __alfresco__]
# nwrowserr                                [ramiallolah, wayff44rer]
# conflictnews1                                         [mobi_ayubi]
# odulimi                                                 [murasil1]
# searcher                                              [wayff44rer]
# wayff44rer       [mountainjjoool, wwayyf44, muktarbelmuktar, ww...
# q7tc                                                    [murasil1]
# gijveli                                           [mountainjjoool]
# ele7vn           [1texanna, melvynlion, scotsmaninfidel, spicyl...
# ruhaniqal                                             [melvynlion]
# theislamapp                                           [melvynlion]
# adlenmeddi                                         [uncle_samcoco]
# amnestyonline                                      [uncle_samcoco]
# muslimfromchina                                           [ro34th]
# jobahout                                                  [ro34th]
# 481437                           [04_8_1437, 04_8_1437, 04_8_1437]
# jdanteff                          [mountainjjoool, mountainjjoool]
# xxxzzz333                      [0481437, 0481437, 0481, 04_8_1437]
# fr33m9nd                                          [mountainjjoool]
# thehikmah                                             [melvynlion]
# antishirkkkk                                      [mountainjjoool]
# hadjsarrasins                                      [uncle_samcoco]
#
#                                                                doc  \
# gunsandcoffee70   a message to the truthful in syria  sheikh ab...
# giimediach004      rules of imarah part2  conditions of imama @...
# abulaythalhindi      1436919          #breaking #confirmed isla...
# yazeeddhardaa25  [is, syria, aleppo, raqq, islamicstate, damasc...
# abubakerdimshqi  [is, dawlah, cub, mojahdin, saudi, is, doma, s...
# baqiyais         [wilayataljazirah, alshabaab, amisom, updf, is...
# abdelhakzait                                                    []
# cnn                                                   [isis, isis]
# pieternanninga   [is, sinai, egyptian, is, is, is, jakarta, is,...
# muslimprisoners  [freemuslimprisoner, freemuslimprisoner, freem...
# 3bdulkaed6r                                                     []
# syrializer                           [syria, palmyra, islamicstat]
# ramiallolah      [drones, isis, iraqi, turkey, pkk, twitterkurd...
# sakirkhader      [is, isis, iraqi, russia, syrian, syria, syria...
# thejokerdc                                                      []
# islamreligion                                                   []
# markito0171      [russian, syrias, homs, syria, islamicstate, a...
# sta92                                                           []
# ejmalrai         [jn, aq, ahrar, syri, syri, aq, aq, russia, is...
# islamiceyes                                                     []
# aimanofarabia                                                   []
# freealeppo1985                                                  []
# ayyx3                                                           []
# pray4pal                                          [gazaunderattac]
# whitecat_7                                        [is, is, is, is]
# netzpolitik                                                     []
# amanlikeme                                                      []
# eyeonmilitant           [syria, hom, yemen, houthis, saudi, jizan]
# jihadologynet                                                  [4]
# conflicts        [latakia, syria, turkey, syria, parisattacks, ...
# ...                                                            ...
# iraqispringmc                                                   []
# globallibz                                                      []
# saiyansyrian                                                    []
# observateurs                                                    []
# wsj                                                             []
# joogaza                                         [salfet, palestin]
# phmarliere                                                      []
# cnnturkeng                                            [sancaktepe]
# mountainkkpouio                                                 []
# nwrowserr                                                       []
# conflictnews1                                               [isis]
# odulimi                                      [sadr, iraqi, baghda]
# searcher                                                        []
# wayff44rer                            [sinai, sinai, sinai, sinai]
# q7tc                                    [amaqagency, rutbah, anba]
# gijveli                                                         []
# ele7vn                                                          []
# ruhaniqal                                                       []
# theislamapp                                                     []
# adlenmeddi                                                   [alg]
# amnestyonline                                                   []
# muslimfromchina            [savemuslimcommunity, chinakillsmuslim]
# jobahout                                          [syria, israeli]
# 481437                                                          []
# jdanteff                      [pt, islamicstate, isf, ramadi, isi]
# xxxzzz333                                                       []
# fr33m9nd                                                        []
# thehikmah                              [ibnalqayyim, allah, alqal]
# antishirkkkk                                                    []
# hadjsarrasins                                                   []
#
#                                                             tweets
# gunsandcoffee70  [a message to the truthful in syria  sheikh ab...
# giimediach004    [ rules of imarah part2  conditions of imama @...
# abulaythalhindi  [   1436919         , #breaking #confirmed isl...
# yazeeddhardaa25  [salamu alaykum im back do supports and spread...
# abubakerdimshqi  [best generation ever takbirrr #is #dawlah #cu...
# baqiyais         [report jn tells their fighters they wont part...
# abdelhakzait        [ @nasseralfahad0            @abubakerdimshqi]
# cnn              [ photo of israeli soldier holding palestinian...
# pieternanninga   [ new 37min video #is #sinai prov snipers vbie...
# muslimprisoners  [ bothers amp sisters plz show determination i...
# 3bdulkaed6r      [ russian troops fighting alongside assads arm...
# syrializer       [ #syria isis destroys more ancient artifacts ...
# ramiallolah      [ #drones footage taken prior an #isis massive...
# sakirkhader      [ shocking footage apparently shows the bodies...
# thejokerdc            [ came to the wrong manor  @yazeeddhardaa25]
# islamreligion    [ why do muslims eat halal meat       @abubake...
# markito0171      [ #russian combat forces in #syrias desert of ...
# sta92                        [                   @yazeeddhardaa25]
# ejmalrai         [ #jn #aq spokesperson harshly attack #ahrar a...
# islamiceyes      [ nabi saw said no one who has the weight of a...
# aimanofarabia    [ a summary of what happened in masjid al aqsa...
# freealeppo1985                [ #      #  #      @abubakerdimshqi]
# ayyx3            [ subhan allh its amazing how we can love and ...
# pray4pal         [ crisis electricity water oil no work no rebu...
# whitecat_7       [@khadijavf she did that to me toojust search ...
# netzpolitik      [ we unveil the german secret service bnd plan...
# amanlikeme       [ 2 secondly the syrians have not been given s...
# eyeonmilitant    [ #syria daesh claims a suicide attack in the ...
# jihadologynet    [ statement from the islamic state of iraq to ...
# conflicts        [ yemen isis branch says its behind mosque bla...
# ...                                                            ...
# iraqispringmc                  [                  @mountainjjoool]
# globallibz       [ breaking al anbar iraqi army n militias bein...
# saiyansyrian     [ if i had a dollar for every time assad has r...
# observateurs     [ meurs fils de p a nous est gal la police tun...
# wsj              [ with iranbacked conversions shiites gain gro...
# joogaza          [ zionists forces arrested early this morning ...
# phmarliere       [ laurence rossignol est moins critique dun mi...
# cnnturkeng       [ breaking explosion in a car reported in ista...
# mountainkkpouio  [ he says islamic state again surrounds the an...
# nwrowserr        [ is fighters controls albufarraj and albuaith...
# conflictnews1    [ saa helicopter downed by #isis defenses near...
# odulimi          [ a large demonstration is taking place in #sa...
# searcher                                            [ @wayff44rer]
# wayff44rer       [   @mountainjjoool, position of ahlu sunnah o...
# q7tc             [ #amaqagency aftermath of us airstrikes on #r...
# gijveli                   [    100          #     @mountainjjoool]
# ele7vn           [ @1texanna @melvynlion @scotsmaninfidel @spic...
# ruhaniqal                                           [ @melvynlion]
# theislamapp      [ being muslim isnt always easy but it gives u...
# adlenmeddi       [ ennahar tv  rebrab a donn 600 millions de ce...
# amnestyonline    [ today daraya civilians awaited 1st aid since...
# muslimfromchina  [ facts about muslims communities u should kno...
# jobahout         [ big breaking news mustafa badreddine highest...
# 481437           [ #    #      #      @04_8_1437,  #  #     #  ...
# jdanteff         [ #pt  happy #islamicstate soldiers on their w...
# xxxzzz333             [      @0481437  @0481437  @0481 @04_8_1437]
# fr33m9nd         [ some shiites have reported that angels are h...
# thehikmah         [ #ibnalqayyim #allah taaala #alqal @melvynlion]
# antishirkkkk     [ a single expedition in the afternoon or fore...
# hadjsarrasins    [ mais qui a envie dentendre quelquun faire du...
#
# [1577 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize = (20,15))
style.use('fivethirtyeight')



df['topic'] = np.argmax(model.transform(Tfidf_vectorizer.transform(df.tweets)), axis=1)
top10_users = df[df.username.isin(df.username.value_counts()[:10].keys().tolist())]
tb = pd.crosstab(top10_users.username, top10_users.topic)
tb['sum'] = tb.sum(axis=1)
#pd.crosstab(top10_users.username, top10_users.topic).plot(kind='barh',stacked=True, figsize=(16, 10), colormap="gist_heat", ax = ax)
tb.sort_values('sum', ascending=False).iloc[:,:5].plot(kind='barh',stacked=True, figsize=(16, 10), colormap="gist_heat", ax =ax)

ax.set_title('10 Most Frequent Users')
ax.set_xlabel('Number of Tweets')
