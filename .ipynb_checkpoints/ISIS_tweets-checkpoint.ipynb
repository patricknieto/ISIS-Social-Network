# %%
import pandas as pd
import csv
import os
import numpy
import copy
# %matplotlib inline
import numpy as np
import seaborn as sns
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from gensim import corpora, models, similarities, matutils
from gensim.corpora.dictionary import Dictionary
from sklearn.cluster import DBSCAN
from sklearn.decomposition import NMF, PCA
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

#Some nice plotting params
mpl.rcParams['figure.figsize'] = (8,5)
mpl.rcParams['lines.linewidth'] = 3
plt.style.use('ggplot')

# %% [markdown]
# # Load ISIS data set and clean tweets

# %%
df = pd.read_csv('/media/patrick/MY_EXTERNAL/ISIS/tweets.csv', parse_dates= [6])

# %%
def clean_tweet(tweet):
    ext = "http"
    text = tweet[:tweet.find(ext)].lower()
    text = re.sub("[^\S]", " ", text)
    text = re.sub("english translation ", "", text)
    textOnly = re.sub("[^a-zA-Z0-9@# ]", "", text)
    return(textOnly)

# %%
df.tweets = df.tweets.apply(clean_tweet)

# %%
docs = []
for username in df.username.unique():
    words = ''
    for tweet in df[df.username == username].tweets:
        words = words + ' ' + tweet
    docs.append(words)

# %% [markdown]
# ### Treat all the tweets from one user as a single document and vectorize

# %%
Tfidf_vectorizer = TfidfVectorizer(analyzer='word',
                                  ngram_range=(1,3), stop_words='english',
                                  token_pattern='\\b[a-z][a-z]+\\b')
tfidf_tweets = Tfidf_vectorizer.fit_transform(docs)

# %%
count_vectorizer = CountVectorizer(analyzer='word',
                                  ngram_range=(1,3), stop_words='english',
                                  token_pattern='\\b[a-z][a-z]+\\b')
cv_tweets = count_vectorizer.fit_transform(docs)

# %% [markdown]
# --------------------------------------------------------------------------

# %%
from sklearn.utils.extmath import randomized_svd
U, Sigma, VT = randomized_svd(cv_tweets, n_components=15,
                                      n_iter=5,
                                      random_state=None)

# %%
sigma = []
for k,v in enumerate(Sigma):
    sigma.append((k,v))

# %%
f = plt.scatter(*zip(*sigma))

# %% [markdown]
# Based on the sigma values from the resulting matrix we can choose a about 5 components to use in our NMF model in order to explain the most.....?

# %% [markdown]
# ### NMF decomposition

# %%
from collections import Counter, defaultdict

import seaborn as sns
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.metrics.pairwise import cosine_similarity

# %%
num_topics = 5
model = NMF(n_components=num_topics, init='random', random_state=0)
nmf = model.fit_transform(tfidf_tweets.toarray())

# %%
doc_cluster = [list(r).index(max(r)) for r in nmf]

# %%
print (doc_cluster[0:20])
print (doc_cluster[41:60])
print (doc_cluster[61:80])
print( doc_cluster[-40:-20])
# Out:
# [2, 1, 4, 4, 2, 4, 2, 4, 4, 1, 2, 0, 4, 4, 0, 2, 1, 4, 4, 4]
# [3, 0, 0, 2, 3, 4, 4, 4, 2, 0, 0, 4, 2, 4, 0, 2, 2, 2, 2]
# [4, 4, 4, 4, 4, 4, 0, 4, 4, 4, 4, 2, 4, 2, 0, 4, 4, 4, 2]
# [2, 4, 2, 0, 4, 4, 4, 2, 2, 4, 2, 0, 2, 2, 1, 2, 2, 4, 2, 4]

# %%
cluster_size = [0,0,0,0,0]
for v in doc_cluster:
    cluster_size[v]+=1
cluster_size
# Out:
# [20, 11, 26, 6, 49]

# %%
docs[2]
# Out:
# ' salamu alaykum im back do supports and spread my new account barakallahu feekum  @yazeeddhardaa25 cc @ibnnuhas @jazrawiuod @striv3ride @afroqaqaisbac @baqiya58 jazakallahu akh @umulbanat1 jazakallahu uk @aljabarti22 jazakallahu ak @ummaysha20 jazakallahu ukhti @abtigood @asadalkanadi1 @bintrose33 jazakallahu ukhti @abuhaleema28 @skxxx50 @abtigood @muslimah1 @jasonphedo @aljabali23 @abdullahkayaniw @checkcontent @skxx51 actually he has been changed drastically after is took a revenged and encircled them in dez @striv3ric @warreports 1 @skxx51 he cant accept the mubahala between sh adnani amp abu abdullah shami where the truth is on is @striv3ric @warreports 2 @skxx51 if all of you remember his tweets from his first acc he used to support is and made a clarification the @striv3ric @warreports3 @skxx51 truth behind jan13 where hes asserted that fsa the one who start the infighting and killing muhajireen @striv3ric @warreports4 @skxx51 those who doesnt know him will says that his tweet
# ...

# %%
docs[3]
# Out:
# ' best generation ever takbirrr #is #dawlah #cubs  rt @abdelhakzait @nasseralfahad0              ameen #mojahdin #saudi   #is #doma   #    #                  pls share brothers and sisters    #  rt @cnn photo of israeli soldier holding palestinian boy in headlock goes viral  @tawheed1is but one is important to live when the other one is not the word of the week  @ironmuhajir2 @jundhullah14  nothing like jihad god give us the help and power to do our farrid my heart is tears blood every day for those kids from the occupied #syria my loved country  rt @muslimprisoners bothers amp sisters plz show determination if the haters never trier banning abu haleemah we should never stop our sho rt @muslimprisoners mainstream media reporting that @anjemchoudary has 10 bail conditions  thx god our lovely shiekh is free  wish to meet you soon teacher and wish the freedom for all brothers in preson  rt @islamreligion why do muslims eat halal meat         pls re tweet   there is no good in us if the 
# ...

# %%
user_docs = {}
for k, cluster in enumerate(doc_cluster):
    user_docs[df.username.unique()[k]] = cluster

# %%
df[df.tweets.str.contains('best geaneration ever takbirrr', na=False)].username
# Out:
# 33    abubakerdimshqi
# Name: username, dtype: object

# %%
df[df.tweets.str.contains('salamu alaykum im back do supports', na=False)].username
# Out:
# 31    YazeedDhardaa25
# Name: username, dtype: object

# %%
cos_sim = cosine_similarity(model.components_,model.components_)

# %%
ax_1 = sns.heatmap(cos_sim, cmap="RdBu_r", annot=False)

# %%
words = sorted([(i,v) for v,i in Tfidf_vectorizer.vocabulary_.items()])
topic_words = []
for r in model.components_:
    a = sorted([(v,i) for i,v in enumerate(r)],reverse=True)[0:7]
    topic_words.append([words[e[1]] for e in a])

# %%
topic_words
# Out:
# [[(116232, 'isis'),
#   (199474, 'rt'),
#   (233606, 'syria'),
#   (129849, 'killed'),
#   (25036, 'army'),
#   (10744, 'aleppo'),
#   (269089, 'ypg')],
#  [(17242, 'amaqagency'),
#   (120028, 'islamicstate'),
#   (42259, 'breaking islamicstate'),
#   (41979, 'breaking'),
#   (17385, 'amaqagency islamicstate'),
#   (120181, 'islamicstate fighters'),
#   (86238, 'fighters')],
#  [(18556, 'amp'),
#   (226724, 'state'),
#   (119685, 'islamic state'),
#   (119534, 'islamic'),
#   (63753, 'dawlah'),
#   (13261, 'allah'),
#   (133064, 'kronykal')],
#  [(51594, 'city'),
#   (45802, 'caliphatenew'),
#   (45848, 'caliphatenews'),
#   (263944, 'wilayatninawa'),
#   (120028, 'islamicstate'),
#   (263775, 'wilayathalab'),
#   (10278, 'albattarengl')],
#  [(199474, 'rt'),
#   (13261, 'allah'),
#   (188211, 'ramiallolah'),
#   (204118, 'rt ramiallolah'),
#   (18556, 'amp'),
#   (116232, 'isis'),
#   (174015, 'people')]]

# %% [markdown]
# -----

# %% [markdown]
# --------

# %%
# Convert sparse matrix of counts to a gensim corpus
corpus = matutils.Sparse2Corpus(ng_vecs)
# Out:
# (120055, 17410)

# %%
dictionary = Dictionary.from_corpus(corpus,
                                    id2word=dict((id, word) for word, id in count_vectorizer.vocabulary_.items()))

# %%
# Build an LSI space from the input TFIDF matrix, mapping of row id to word, and num_topics
# num_topics is the number of dimensions to reduce to after the SVD
# Analagous to "fit" in sklearn, it primes an LSI space
lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=300)

# %%
lsi_corpus = lsi[corpus]

# %%
# Dump the resulting documentwe vectors into a list so we can take a look
doc_vecs = [doc for doc in lsi_corpus]

# %%
# Create an index transformer that calculates similarity based on our space
index = similarities.MatrixSimilarity(doc_vecs)
# Out:
# WARNING:gensim.similarities.docsim:scanning corpus to determine the number of features (consider setting `num_features` explicitly)

# %%
# Return the sorted list of cosine similarities to the first document
sims = sorted(enumerate(index[doc_vecs[1]]), key=lambda item: -item[1])
sims[:50]
# Out:
# [(1, 1.0),
#  (2, 0.84271097),
#  (8357, 0.78651285),
#  (6754, 0.72929001),
#  (3, 0.69600505),
#  (12, 0.68095952),
#  (13325, 0.67608559),
#  (28, 0.66332865),
#  (13, 0.63348162),
#  (0, 0.63070279),
#  (688, 0.59702998),
#  (7034, 0.58836848),
#  (4, 0.56046808),
#  (8524, 0.55894303),
#  (4411, 0.55621219),
#  (7627, 0.54944879),
#  (6634, 0.5440135),
#  (963, 0.53972322),
#  (7313, 0.5395205),
#  (3102, 0.53789008),
#  (5099, 0.53649491),
#  (8085, 0.53643519),
#  (1182, 0.53636241),
#  (1228, 0.53636241),
#  (8734, 0.53442222),
#  (7626, 0.53364033),
#  (9546, 0.53303421),
#  (1541, 0.53127444),
#  (7648, 0.52960968),
#  (11091, 0.52947271),
#  (14246, 0.52917862),
#  (10282, 0.52836823),
#  (8564, 0.52706933),
#  (3120, 0.52614129),
#  (3141, 0.52614129),
#  (3213, 0.52614129),
#  (3975, 0.52614129),
#  (4014, 0.52614129),
#  (4047, 0.52614129),
#  (15488, 0.52430135),
#  (8728, 0.52261585),
#  (15210, 0.52225399),
#  (12740, 0.52115667),
#  (13310, 0.5202269),
# ...

# %%
tweetList[12]
# Out:
# ' sheikh abu hasan al kuwaiti ha advice of nabi saw to the mujahid'

# %%
tweetList[3]
# Out:
# ' sheikh nasir al wuhayshi ha leader of aqap the promise of vict'

# %% [markdown]
# Examples of clergy they like the most: “Anwar Awlaki”, “Ahmad Jibril”, “Ibn Taymiyyah”, “Abdul Wahhab”. Examples of clergy that they hate the most: “Hamza Yusuf”, “Suhaib Webb”, “Yaser Qadhi”, “Nouman Ali Khan”, “Yaqoubi”.

# %%
dbscan = DBSCAN(random_state=111)
dbscan
# Out:
# DBSCAN(algorithm='auto', eps=0.5, leaf_size=30, metric='euclidean',
#     min_samples=5, p=None, random_state=111)

# %%
dbscan.labels_

# %% [markdown]
# ## Creating Graph Edges

# %% [markdown]
# #### Currently:
# We have occurences of username strings in all tweets from each user
#
#
# #### We would like:
# agrregated pairwise co-occurrence of character strings in tweet for each username, Normalized by the sum of all tweet from both usernames being compared.

# %%
def is_retweet(tweet):
    match = re.search('^rt', tweet)
    if match:
        return True
    return False

# %%
def check_string(string):
    return string in df.username.unique()

# %%
edgeDict = {}
for username in df.username.unique():
    user = {}
    user['affil'] = []
    user['hashtags'] = []
    user['tweets'] = []
    user['rts'] = []
    user['orig'] = []
    words = ''
    for tweet in df[df.username == username].tweets:
        words = words + ' ' + tweet
        user['affil'].extend(re.findall('(?<=@)\w+', tweet))
        user['hashtags'].extend(re.findall('(?<=#)\w+', tweet))
        user['tweets'].append(tweet)
        match = re.search('^rt', tweet)
        if match:
            user['rts'].append(tweet)
        else:
            user['orig'].append(tweet)
            
    user['hashtags'] = list(set(user['hashtags']))
    user['words'] = words
    edgeDict[username] = user

# %%
nodes = defaultdict(str)
for k, v in edgeDict.items():
    nodes[k] = [(k, v) for k,v in Counter(list(filter(check_string, (v['affil'])))).items()]
for k, v in list(nodes.items()):
    if not v:
        del nodes[k]

# %%
#create dictionary that maps usernames to a uniqe ID and the cluster they belong to
ID = defaultdict()
for k, v in enumerate(list(nodes.items())):
    ID[v[0]] = k, user_docs[v[0]]
    print(ID[v[0]])
    for i in range(0, len(v[1])):
        ID[v[1][i][0]] = k, user_docs[v[1][i][0]]
        print(ID[v[1][i][0]])
# Out:
# (0, 4)
# (0, 2)
# (1, 4)
# (1, 3)
# (2, 4)
# (2, 0)
# (2, 0)
# (3, 4)
# (3, 0)
# (3, 0)
# (3, 0)
# (3, 0)
# (4, 0)
# (4, 0)
# (5, 2)
# (5, 3)
# (5, 2)
# (6, 4)
# (6, 2)
# (7, 4)
# (7, 4)
# (8, 4)
# (8, 3)
# (9, 0)
# (9, 2)
# (9, 0)
# (9, 2)
# (10, 1)
# (10, 4)
# (11, 4)
# (11, 0)
# (12, 4)
# (12, 4)
# (13, 2)
# (13, 4)
# (14, 0)
# (14, 0)
# (15, 4)
# (15, 4)
# (15, 2)
# (16, 4)
# (16, 0)
# (17, 0)
# (17, 0)
# (17, 0)
# (17, 4)
# (18, 4)
# (18, 2)
# (19, 4)
# (19, 2)
# (20, 0)
# (20, 0)
# (21, 0)
# (21, 0)
# (21, 0)
# (22, 4)
# (22, 0)
# (23, 3)
# (23, 3)
# (24, 4)
# (24, 0)
# (25, 4)
# (25, 4)
# (25, 0)
# (26, 0)
# (26, 3)
# (27, 4)
# (27, 4)
# (27, 4)
# (27, 0)
# (27, 0)
# (28, 0)
# (28, 4)
# (28, 0)
# (29, 2)
# (29, 2)
# (30, 2)
# (30, 0)
# (31, 0)
# (31, 4)
# (31, 0)
# (32, 4)
# (32, 4)
# (32, 0)
# (32, 4)
# (33, 4)
# (33, 4)
# (34, 2)
# (34, 0)
# (35, 4)
# (35, 0)
# (35, 4)
# (36, 4)
# (36, 2)
# (37, 1)
# (37, 1)
# (37, 0)
# (38, 2)
# (38, 2)

# %%
ID
# Out:
# defaultdict(None,
#             {'06230550_IS': (6, 4),
#              '1515Ummah': (26, 0),
#              '432Mryam': (33, 4),
#              'Abu_Azzzam25': (12, 4),
#              'AsimAbuMerjem': (14, 0),
#              'FidaeeFulaani': (5, 2),
#              'IbnKashmir_': (22, 4),
#              'Jazrawi_Saraqib': (30, 2),
#              'MaghrabiArabi': (17, 0),
#              'ManKhalfahum': (8, 4),
#              'MilkSheikh2': (13, 2),
#              'Mountainjjoool': (37, 1),
#              'NaseemAhmed50': (35, 4),
#              'Nidalgazaui': (4, 0),
#              'Uncle_SamCoco': (28, 0),
#              'WarReporter1': (9, 0),
#              '_IshfaqAhmad': (11, 4),
#              '__alfresco__': (27, 4),
#              'abuayisha102': (33, 4),
#              'abuayisha108': (18, 4),
#              'abuhumayra4': (36, 4),
#              'abutariq041': (15, 4),
#              'ansarakhilafa': (17, 4),
#              'baaqiya_01': (19, 4),
# ...

# %%
pd.DataFrame(ID).T.to_csv('nodes.csv')

# %%
new_dict = {}
for k, v in nodes.items():
    for i in range(len(v)):
        new_dict[ID[[k][0]][0], ID[v[i][0]][0]] = v[i][1]

# %%
pd.DataFrame([[k[0],k[1],v] for k, v in new_dict.items()]).to_csv('edges.csv')

# %%
for k, v in edgeDict.items():
    edgeDict[k] = [word for item in v for word in item if word in list(set(df.username))]
for k, v in list(edgeDict.items()):
    if not v:
        del edgeDict[k]

# %%
for k, v in edgeDict.items():
    for name in v:
        if name == k:
            v.remove(name)

# %%
# create a list
i = {}
for k, v in edgeDict.items():
        i[k] = v[0].most_common()
        
        #i.append(user)

# %%
#create a list of all mentioned users using the '@'
i = []
for k, v in edgeDict.items():
    for user in v[0]:
        i.append(user)

# %%
Counter(i).most_common()[:25]
# Out:
# [('ramiallolah', 51),
#  ('nidalgazaui', 33),
#  ('7layers', 24),
#  ('conflicts', 23),
#  ('warreporter1', 22),
#  ('markito0171', 17),
#  ('khateebdimashqi', 16),
#  ('middleeasteye', 16),
#  ('nusantarwitness', 16),
#  ('ajenews', 15),
#  ('unclesamcoco', 14),
#  ('warrnews', 14),
#  ('alamrikiomar', 13),
#  ('shamirebel', 13),
#  ('pvanostaeyen', 13),
#  ('pieternanninga', 12),
#  ('qassamimarwan', 12),
#  ('terrormonitor', 12),
#  ('tracterrorism', 11),
#  ('wayf44rer', 11),
#  ('moonnor27', 11),
#  ('vivarevolt', 11),
#  ('charleslister', 11),
#  ('northernstork', 11),
#  ('afp', 11)]

# %%
a = a.T

# %%
a['user'] = edgeDict.keys()
a.set_index('user')
# Out:
#                    #  ##hezbollah  ##jihad  #1  #10yearsblockade  #11  \
# user
# mustafaklash56   NaN          NaN      NaN NaN               NaN  NaN
# WarReporter1       3          NaN      NaN NaN               NaN  NaN
# ALK___226         17          NaN      NaN NaN               NaN  NaN
# baaqiya_01       NaN          NaN      NaN NaN               NaN  NaN
# Abu_Ibn_Taha       1          NaN      NaN NaN               NaN  NaN
# abuhumayra4        1          NaN      NaN NaN               NaN  NaN
# Abdul__05        NaN          NaN      NaN NaN               NaN  NaN
# JoinISNation102    2          NaN      NaN   1               NaN  NaN
# abubakerdimshqi   13          NaN      NaN NaN               NaN  NaN
# MhzBnt           NaN          NaN      NaN NaN               NaN  NaN
# freelance_112      1          NaN      NaN NaN               NaN  NaN
# QassamiMarwan      6          NaN      NaN NaN               NaN  NaN
# ...

# %%
df['hour'] = [item.hour for item in df.time]

df_time = df[['tweets', 'time']]

df_time.groupby('time').count().plot(kind ='bar', figsize=(15,8), legend =False)

# %%
df_time.tweets.value_counts()
# Out:
# 19    1397
# 18    1385
# 20    1366
# 21    1198
# 17    1110
# 15    1088
# 14    1060
# 16    1009
# 22     978
# 13     917
# 12     755
# 10     640
# 23     637
# 11     634
# 9      568
# 6      390
# 8      390
# 0      387
# 7      348
# 1      293
# 5      259
# 2      221
# 4      216
# 3      164
# Name: hour, dtype: int64

# %%
pd.DataFrame(df_time.time.value_counts()).reset_index().sort_values('index').plot(kind='bar')

# %%
tsh = df.set_index(pd.DatetimeIndex(df['time']))

# %%
perhr = tsh.resample('12H', how='count')

# %%
list(tsh['2016-01-31'].tweets)
# Out:
# ['these incidents are increasing amp becaming quite notable #isis shot down a combat #usa drone over #karmah #iraq ',
#  '@middleeasteye picture is unrelated',
#  'rt @arabparachute first time on twitter will the muslims be kind enough to share my account',
#  'bruce schneier security expert explains why intelligence agencies are freaking out regarding #is using twitter  ',
#  '@abunaseeha03 from 6 min to around 10 minute',
#  'assad regime fires 60  rockets into a refugee camp in latika  inna ilayhi wa inna ilayhi rajiun  ',
#  '@ibnks777 ameen',
#  'muslims in uk top 3 million for first time with over 50 born abroad ',
#  'subhanallah a snake latches onto body inside the grave may allah protect us from the punishment of the grave  ',
#  'rt @alhashimiya4 ',
#  'game on come on',
#  '@espncricinfo ellyse perry you beauty d ',
#  'rt @espncricinfo ellyse perrys allround show seals a win for australia women at the scg and prevents an india clean sweep  ',
# ...

# %%
fig = plt.figure(1, figsize=(17, 6))
plt.plot(perhr[750:].index.values, perhr[750:].tweets)
plt.show()

# %%
ts = time_series.values.ravel()

# %%
import datetime as dt
def f(x): # I don't really care about the times that the tweets were made
    #print(dt.datetime(x.year,x.month,x.day))
    return (dt.datetime(x.year,x.month,x.day))

df['time'] = df.time.apply(f)

time_series = pd.DataFrame(df.time.value_counts().sort_index().resample('D').mean().fillna(0))
time_series.columns = ['Tweets']

time_series.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-190-46302db1eddd> in <module>()
#       4     return (dt.datetime(x.year,x.month,x.day))
#       5
# ----> 6 df['time'] = df.time.apply(f)
#       7
#       8 time_series = pd.DataFrame(df.time.value_counts().sort_index().resample('D').mean().fillna(0))
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2167             values = lib.map_infer(values, lib.Timestamp)
#    2168
# -> 2169         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2170         if len(mapped) and isinstance(mapped[0], Series):
#    2171             from pandas.core.frame import DataFrame
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62578)()
#
# <ipython-input-190-46302db1eddd> in f(x)
# ...

# %%
df.time.value_counts()
